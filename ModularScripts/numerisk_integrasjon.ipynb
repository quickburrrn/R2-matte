# %% [markdown]
# # Numerisk integrasjon
#
# Her kan man utføre numerisk integrasjon med de ulike rektangelmetodene og trapesmetoden, den bruker formler basert på syke formel dokumentet

# %%
import math

# funksjonen som skal integreres
def f(x):
    # if x == 0:
    #     return 0 

    return 1/(2*math.sqrt(x))

a = 0 # start
b = 3 # slutt
n = 10000000 # oppløsning

d = (b-a)/n
S = 0

# Kommenter ut de tilnermingene du ikke skal bruke

for i in range(1, n+1):
    pass
    #S += f(a + (i - 1) * d) * d # venstretilnerming
    
    #S += f(a + i * d) * d # høyretilnærmings

    S += f(a + (i - 1/2) * d) * d # Midtpunkttilnærming RectangleSum(f, a, b, n, 1 / 2) i GeoGebra

# Trapesmetoden TrapezoidalSum(f, a, b, n) i GeoGebra
# for i in range(1, n):
#     S += f(a + i * d)
# S = (d/2) * (f(a) + f(b) + 2 * S)

print(S)
# Out:
# 1.7318851492529175
