# %% [markdown]
# # Rekkeskriver
# Dette er program som skriver en rekke ikke så mye mer

# %%
def a(n): # eksplisitt
    return 2 + (n-1) * ((n-1) + 2)

# def a(n): # rekursiv
#     if n == 1:
#         return 2
#     return a(n-1) + (n-1) + 2

for n in range(1, 6):
    print(a(n))
# Out:
# 2
# 7
# 14
# 23
# 34
