# %%
a_1 = 1
end = 10

def a(n):
    if n == 1:
        return a_1
    else:           # statement
        return a(n-1) + 2**(n-1)
        #return 2 * a(n-1) + 1

for n in range(1, 11):
    print(f"F({n}) {a(n)} ?= {2**(n)-1}")
# Out:
# F(1) 1 ?= 1
# F(2) 3 ?= 3
# F(3) 7 ?= 7
# F(4) 15 ?= 15
# F(5) 31 ?= 31
# F(6) 63 ?= 63
# F(7) 127 ?= 127
# F(8) 255 ?= 255
# F(9) 511 ?= 511
# F(10) 1023 ?= 1023
