# %% [markdown]
# ### Prøver å finne python formel for $a_n=1+\sum \limits_{i=1}^{n}i$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("hello world")

x = np.linspace(0, 50, 200)
y = np.linspace(0, 100, 200)

x_1 = np.linspace(1,6, 200)
y_1 = x_1**2

testy = x_1**1.5

n2x = [1, 2, 3, 4, 5, 6]
n2y = [1, 4, 9, 16, 25, 36]

n1x = [1, 2, 3, 4, 5, 6]
n1y = [1, 2, 4, 7, 11, 16]

fig, ax = plt.subplots()
# ax.plot(x, y)
ax.plot(x_1, y_1)
ax.scatter(n2x, n2y)
ax.scatter(n1x, n1y)
ax.plot(x_1, testy)

# plt.gca().set_aspect(1)

plt.grid(True)
plt.show()
# Out:
# hello world
