# %% [markdown]
# Bruk den rekursive formelen du fant i oppgave a), og lag et program som
# regner ut summen av de 30 første leddene i tallfølgen
#
# Testter også rekka her

# %%
def c(n):
    # if n == 1:
    #     return 3
    # else:
    #     return c(n-1) + 2n

    return 3 + (n-1)*2

def b(n):
    # if n == 1:
    #     return 1
    # else:
    #     return b(n-1) + 3 + (n-2)*2

    return 1 + (n-1)*(3 + (n-2)*2)

def a(n):
    if n == 1:
        return 1
    else:
        return a(n-1) + b(n-1)

# def a(n):
#     if n == 1:
#         return 1
#     else:
#         return a(n-1) + 1 + (n-1)*(3+(n-1)*2)
    
for i in range(1, 10):
    #print(a(i))
    print(b(i))
# Out:
# 1
# 4
# 11
# 22
# 37
# 56
# 79
# 106
# 137
